# %% [markdown]
# # 🏫 ZSEL Opole - Private Cloud Architecture
# ## 39 Applications & Services Deployment Plan
#
# **Infrastructure:** K3s Kubernetes Cluster (9 Mac Pro nodes)
# **Network:** 26 VLANs, 57 MikroTik devices, 10 Gbps core
# **Users:** 1030 (900 students + 100 teachers + 30 staff)
# **Domains:** 6 (zsel.opole.pl, bcu.com.pl, sue.opole.pl, mrsu.pl, elektryk.opole.pl, k4tec.pl)
#
# **Last Updated:** 2025-11-25
# **Status:** Production-Ready Architecture

# %% [markdown]
# ## 1. Import Required Libraries
#
# Import necessary Python libraries for Kubernetes management, data visualization, and configuration handling.

# %%
# Import Required Libraries
import pandas as pd
import yaml
import json
from datetime import datetime
from collections import defaultdict
import matplotlib.pyplot as plt
import networkx as nx

# Configuration
CLUSTER_NAME = "zsel-k3s-prod"
TOTAL_NODES = 9
TOTAL_USERS = 1030
DOMAINS_COUNT = 6
NETWORK_BANDWIDTH_GBPS = 10

print(f"✅ Libraries imported successfully")
print(f"📊 Cluster: {CLUSTER_NAME} ({TOTAL_NODES} nodes)")
print(f"👥 Users: {TOTAL_USERS}")
print(f"🌐 Domains: {DOMAINS_COUNT}")

# %% [markdown]
# ## 2. Define Complete Application Architecture
#
# **39 Applications** organized across **10 Namespace Categories**:
#
# 1. **Core Infrastructure** (6 apps) - Critical services
# 2. **Security & Monitoring** (10 apps) - Security, audit, monitoring
# 3. **Education** (8 apps) - Learning platforms
# 4. **DevOps** (5 apps) - Development tools
# 5. **AI & Lab** (6 apps) - AI services, virtualization
# 6. **Communication & Web** (4 apps) - Email, websites, databases
